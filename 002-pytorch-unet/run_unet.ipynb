# %%
# !python3 './drive/MyDrive/002-pytorch-unet/data_read.py'
# Out:
# Figure(640x480)

# %%
# !python3 '/content/drive/MyDrive/002-pytorch-unet/train.py' \
--lr 1e-3 --batch_size 2 --num_epoch 100 \
--data_dir "/content/drive/MyDrive/002-pytorch-unet/datasets" \
--ckpt_dir "/content/drive/MyDrive/002-pytorch-unet/checkpoint" \
--log_dir "/content/drive/MyDrive/002-pytorch-unet/log" \
--result_dir "/content/drive/MyDrive/002-pytorch-unet/result" \
--mode "train" \
--train_continue "off"
# Out:
# learning rate: 1.0000e-03
# batch size: 2
# number of epoch: 100
# data dir: /content/drive/MyDrive/002-pytorch-unet/datasets
# ckpt dir: /content/drive/MyDrive/002-pytorch-unet/checkpoint
# log dir: /content/drive/MyDrive/002-pytorch-unet/log
# result dir: /content/drive/MyDrive/002-pytorch-unet/result
# mode: train
# train continue: off
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# TRAIN: EPOCH 0001 / 0100 | BATCH 0001 / 0012 | LOSS 0.7122
# TRAIN: EPOCH 0001 / 0100 | BATCH 0002 / 0012 | LOSS 0.6513
# ...

# %%
# !python3 '/content/drive/MyDrive/002-pytorch-unet/train.py' \
--lr 1e-3 --batch_size 2 --num_epoch 100 \
--data_dir "/content/drive/MyDrive/002-pytorch-unet/datasets" \
--ckpt_dir "/content/drive/MyDrive/002-pytorch-unet/checkpoint" \
--log_dir "/content/drive/MyDrive/002-pytorch-unet/log" \
--result_dir "/content/drive/MyDrive/002-pytorch-unet/result" \
--mode "test" \
--train_continue "off"
# Out:
# learning rate: 1.0000e-03
# batch size: 2
# number of epoch: 100
# data dir: /content/drive/MyDrive/002-pytorch-unet/datasets
# ckpt dir: /content/drive/MyDrive/002-pytorch-unet/checkpoint
# log dir: /content/drive/MyDrive/002-pytorch-unet/log
# result dir: /content/drive/MyDrive/002-pytorch-unet/result
# mode: test
# train continue: off
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# TEST: BATCH 0001 / 0002 | LOSS 0.2028
# TEST: BATCH 0002 / 0002 | LOSS 0.2034
# AVERAGE TEST: BATCH 0002 / 0002 | LOSS 0.2034
